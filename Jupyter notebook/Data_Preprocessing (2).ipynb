# %% [markdown]
# # WNUT dataset

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/leondz/emerging_entities_17/master/wnut17train.conll", encoding='utf8', header=None, skip_blank_lines=False, sep='\t')
df[1] = np.where(df[1].str.endswith("location"), df[1], "O")
df[1] = df[1].str.replace("location", "LOC")
df["comb"]=df[0] + " " + df[1]
df = df[["comb"]]
df.replace(np.nan,'',regex=True, inplace=True)
df.to_csv("wnut17train.txt", index=False, header=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %% [markdown]
# # BERT-NER Dataset

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/kamalkraj/BERT-NER/dev/data/train.txt", encoding='utf8', skiprows=2, header=None, skip_blank_lines=False, sep=' ')
df = df[[0, 3]]
df[3] = np.where(df[3].str.endswith("LOC"), df[3], "O")
df["comb"]=df[0] + " " + df[3]
df = df[["comb"]]
df.replace(np.nan,'',regex=True, inplace=True)
# df = df.append(pd.Series("", index=df.columns), ignore_index=True)
df.to_csv("BERT-NER_train.txt", index=False, header=False)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/kamalkraj/BERT-NER/dev/data/valid.txt", encoding='utf8', skiprows=2, header=None, skip_blank_lines=False, sep=' ')
df = df[[0, 3]]
df[3] = np.where(df[3].str.endswith("LOC"), df[3], "O")
df["comb"]=df[0] + " " + df[3]
df = df[["comb"]]
df.replace(np.nan,'',regex=True, inplace=True)
df.to_csv("BERT-NER_valid.txt", index=False, header=False)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/kamalkraj/BERT-NER/dev/data/test.txt", encoding='utf8', skiprows=2, header=None, skip_blank_lines=False, sep=' ')
df = df[[0, 3]]
df[3] = np.where(df[3].str.endswith("LOC"), df[3], "O")
df["comb"]=df[0] + " " + df[3]
df = df[["comb"]]
df.replace(np.nan,'',regex=True, inplace=True)
df.to_csv("BERT-NER_test.txt", index=False, header=False)

# %% [markdown]
# # IDRISI dataset

# %%
# !git clone https://github.com/rsuwaileh/IDRISI.git
# Out:
# Cloning into 'IDRISI'...
# remote: Enumerating objects: 1062, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 1062 (delta 108), reused 100 (delta 59), pack-reused 874
# Receiving objects: 100% (1062/1062), 26.15 MiB | 7.45 MiB/s, done.
# Resolving deltas: 100% (325/325), done.
# Checking out files: 100% (274/274), done.

# %%
# %%time
import shutil

path = "/content/" + "IDRISI/LMR/data/"

events = ["california_wildfires_2018", "canada_wildfires_2016", "cyclone_idai_2019", "ecuador_earthquake_2016", 
          "greece_wildfires_2018", "hurricane_dorian_2019", "hurricane_florence_2018", "hurricane_harvey_2017", 
          "hurricane_irma_2017", "hurricane_maria_2017", "hurricane_matthew_2016", "italy_earthquake_aug_2016", 
          "kaikoura_earthquake_2016", "kerala_floods_2018", "maryland_floods_2018", "midwestern_us_floods_2019", 
          "pakistan_earthquake_2019", "puebla_mexico_earthquake_2017", "srilanka_floods_2017"]

train_path_list = []
test_path_list = []
for typ in ['typeless']:
    for case in ['random']:
        for event in events:
            in_path = path + "EN/gold-" + case + "-bilou/" + event 
            train_path = in_path + "/train.txt"
            test_path = in_path + "/dev.txt"
            train_path_list.append(train_path)
            test_path_list.append(test_path)
print(train_path_list)
print(test_path_list)


with open('IDRISI_train_combined.txt','wb') as wfd:
    for f in train_path_list:
        with open(f,'rb') as fd:
            shutil.copyfileobj(fd, wfd)
# Out:
# ['/content/IDRISI/LMR/data/EN/gold-random-bilou/california_wildfires_2018/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/canada_wildfires_2016/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/cyclone_idai_2019/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/ecuador_earthquake_2016/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/greece_wildfires_2018/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_dorian_2019/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_florence_2018/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_harvey_2017/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_irma_2017/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_maria_2017/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_matthew_2016/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/italy_earthquake_aug_2016/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/kaikoura_earthquake_2016/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/kerala_floods_2018/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/maryland_floods_2018/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/midwestern_us_floods_2019/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/pakistan_earthquake_2019/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/puebla_mexico_earthquake_2017/train.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/srilanka_floods_2017/train.txt']
# ['/content/IDRISI/LMR/data/EN/gold-random-bilou/california_wildfires_2018/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/canada_wildfires_2016/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/cyclone_idai_2019/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/ecuador_earthquake_2016/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/greece_wildfires_2018/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_dorian_2019/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_florence_2018/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_harvey_2017/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_irma_2017/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_maria_2017/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/hurricane_matthew_2016/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/italy_earthquake_aug_2016/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/kaikoura_earthquake_2016/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/kerala_floods_2018/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/maryland_floods_2018/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/midwestern_us_floods_2019/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/pakistan_earthquake_2019/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/puebla_mexico_earthquake_2017/dev.txt', '/content/IDRISI/LMR/data/EN/gold-random-bilou/srilanka_floods_2017/dev.txt']
# CPU times: user 3.4 ms, sys: 4.07 ms, total: 7.46 ms
# Wall time: 15.9 ms

# %% [markdown]
# # Combine all datasets

# %%
with open('TRAIN.txt','wb') as wfd:
    for f in ['/content/IDRISI_train_combined.txt', '/content/wnut17train.txt',
              '/content/BERT-NER_train.txt', '/content/BERT-NER_valid.txt', '/content/BERT-NER_test.txt']:
        with open(f,'rb') as fd:
            shutil.copyfileobj(fd, wfd)

# %% [markdown]
# ## Remove multi blank  lines

# %%
import re
with open('TRAIN.txt', 'r+') as sourceFile:
    sourceFileContents = sourceFile.read()
    sourceFileContents = re.sub(r'\n\s*\n', '\n\n', sourceFileContents)
    sourceFile.write(sourceFileContents)

# %% [markdown]
# ## Train file
# #### Keeping LOC tags only

# %%
types = {"Island": "ISL", "State": "STAT", "Continent": "CONT", "City/town": "CITY", "Country": "CTRY",
        "County": "CNTY", "Neighborhood": "NBHD", "District": "DIST", "Road/street": "ST", "Other locations": "OTHR", 
        "Natural Point-of-Interest": "NPOI", "Human-made Point-of-Interest": "HPOI"}

df = pd.read_csv("/content/TRAIN.txt", encoding='utf8', header=None, skip_blank_lines=False, sep=' ')

# Cases of ", O"; handling issues encountered. So dropping
df.drop(df[~df[0].isna() & df[1].isna()].index, inplace=True)

for v in types.values():
    df[1] = df[1].str.replace(v, 'LOC')
df[1] = df[1].str.replace('U-LOC', 'S-LOC')
df[1] = df[1].str.replace('L-LOC', 'E-LOC')

print(df[1].value_counts())

df["comb"]=df[0] + " " + df[1]
df = df[["comb"]]
df.replace(np.nan,'',regex=True, inplace=True)
df.to_csv("TRAIN.txt", index=False, header=False)
# Out:
# O        1347688
# B-LOC      27564
# S-LOC      25440
# E-LOC       5286
# I-LOC       4634
# Name: 1, dtype: int64

# %% [markdown]
# # Validation file

# %%
with open('DEV.txt','wb') as wfd:
    for f in test_path_list:
        with open(f,'rb') as fd:
            shutil.copyfileobj(fd, wfd)

# Make multiple blank lines into one
with open('DEV.txt', 'r+') as sourceFile:
    sourceFileContents = sourceFile.read()
    sourceFileContents = re.sub(r'\n\s*\n', '\n\n', sourceFileContents)
    sourceFile.write(sourceFileContents)


df = pd.read_csv("/content/DEV.txt", encoding='utf8', header=None, skip_blank_lines=False, sep=' ')
df.drop(df[~df[0].isna() & df[1].isna()].index, inplace=True)

for v in types.values():
    df[1] = df[1].str.replace(v, 'LOC')
df[1] = df[1].str.replace('U-LOC', 'S-LOC')
df[1] = df[1].str.replace('L-LOC', 'E-LOC')

print(df[1].value_counts())

df["comb"]=df[0] + " " + df[1]
df = df[["comb"]]
df.replace(np.nan,'', regex=True, inplace=True)
df.to_csv("DEV.txt", index=False, header=False)
# Out:
# O        98816
# S-LOC     3618
# B-LOC      770
# E-LOC      770
# I-LOC      102
# Name: 1, dtype: int64

# %% [markdown]
# # TRAIN.txt and DEV.TXT are the final files

# %%
# %%capture
# !pip install transformers

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

import transformers
from transformers import AutoTokenizer
from transformers import  DistilBertForTokenClassification

from torch.optim import AdamW

import torch
import torch.nn as nn
from torch.optim import SGD
import torch.nn.functional as F
from torch.utils.data import DataLoader

from sklearn.metrics import accuracy_score,f1_score, precision_score, recall_score

# %%
df_train=pd.read_csv("/content/TRAIN.txt", sep='.',  error_bad_lines=False)
# Out:
# b'Skipping line 106: expected 1 fields, saw 2\nSkipping line 115: expected 1 fields, saw 2\nSkipping line 130: expected 1 fields, saw 2\nSkipping line 143: expected 1 fields, saw 2\nSkipping line 151: expected 1 fields, saw 2\nSkipping line 193: expected 1 fields, saw 2\nSkipping line 207: expected 1 fields, saw 2\nSkipping line 279: expected 1 fields, saw 2\nSkipping line 288: expected 1 fields, saw 2\nSkipping line 303: expected 1 fields, saw 2\nSkipping line 315: expected 1 fields, saw 2\nSkipping line 375: expected 1 fields, saw 2\nSkipping line 387: expected 1 fields, saw 2\nSkipping line 411: expected 1 fields, saw 2\nSkipping line 443: expected 1 fields, saw 2\nSkipping line 469: expected 1 fields, saw 2\nSkipping line 478: expected 1 fields, saw 2\nSkipping line 520: expected 1 fields, saw 2\nSkipping line 532: expected 1 fields, saw 2\nSkipping line 541: expected 1 fields, saw 2\nSkipping line 554: expected 1 fields, saw 2\nSkipping line 556: expected 1 fields, saw 2\nSkipping line 604: expected 1 fields, saw 2\nSkipping line 609: expected 1 fields, saw 2\nSkipping line 617: expected 1 fields, saw 2\nSkipping line 659: expected 1 fields, saw 2\nSkipping line 680: expected 1 fields, saw 2\nSkipping line 688: expected 1 fields, saw 2\nSkipping line 826: expected 1 fields, saw 2\nSkipping line 862: expected 1 fields, saw 2\nSkipping line 901: expected 1 fields, saw 2\nSkipping line 918: expected 1 fields, saw 2\nSkipping line 973: expected 1 fields, saw 2\nSkipping line 1003: expected 1 fields, saw 2\nSkipping line 1019: expected 1 fields, saw 2\nSkipping line 1020: expected 1 fields, saw 2\nSkipping line 1044: expected 1 fields, saw 3\nSkipping line 1059: expected 1 fields, saw 2\nSkipping line 1071: expected 1 fields, saw 2\nSkipping line 1081: expected 1 fields, saw 2\nSkipping line 1104: expected 1 fields, saw 2\nSkipping line 1225: expected 1 fields, saw 2\nSkipping line 1226: expected 1 fields, saw 2\nSkipping line 1252: expected 1 fields, saw 2\nSkipping line 1265: expected 1 fields, saw 2\nSkipping line 1269: expected 1 fields, saw 2\nSkipping line 1286: expected 1 fields, saw 2\nSkipping line 1301: expected 1 fields, saw 2\nSkipping line 1315: expected 1 fields, saw 2\nSkipping line 1330: expected 1 fields, saw 2\nSkipping line 1353: expected 1 fields, saw 2\nSkipping line 1396: expected 1 fields, saw 2\nSkipping line 1410: expected 1 fields, saw 2\nSkipping line 1460: expected 1 fields, saw 2\nSkipping line 1470: expected 1 fields, saw 2\nSkipping line 1480: expected 1 fields, saw 2\nSkipping line 1503: expected 1 fields, saw 2\nSkipping line 1514: expected 1 fields, saw 2\nSkipping line 1525: expected 1 fields, saw 2\nSkipping line 1541: expected 1 fields, saw 2\nSkipping line 1578: expected 1 fields, saw 2\nSkipping line 1602: expected 1 fields, saw 2\nSkipping line 1620: expected 1 fields, saw 2\nSkipping line 1684: expected 1 fields, saw 2\nSkipping line 1708: expected 1 fields, saw 2\nSkipping line 1756: expected 1 fields, saw 2\nSkipping line 1779: expected 1 fields, saw 2\nSkipping line 1783: expected 1 fields, saw 2\nSkipping line 1787: expected 1 fields, saw 2\nSkipping line 1808: expected 1 fields, saw 2\nSkipping line 1828: expected 1 fields, saw 2\nSkipping line 1863: expected 1 fields, saw 2\nSkipping line 1870: expected 1 fields, saw 2\nSkipping line 1876: expected 1 fields, saw 2\nSkipping line 1882: expected 1 fields, saw 2\nSkipping line 1886: expected 1 fields, saw 2\nSkipping line 1887: expected 1 fields, saw 2\nSkipping line 1890: expected 1 fields, saw 2\nSkipping line 1900: expected 1 fields, saw 2\nSkipping line 1934: expected 1 fields, saw 2\nSkipping line 1961: expected 1 fields, saw 2\nSkipping line 1996: expected 1 fields, saw 2\nSkipping line 2036: expected 1 fields, saw 2\nSkipping line 2049: expected 1 fields, saw 2\nSkipping line 2073: expected 1 fields, saw 3\nSkipping line 2115: expected 1 fields, saw 2\nSkipping line 2143: expected 1 fields, saw 2\nSkipping line 2183: expected  ...
# b'Skipping line 547423: expected 1 fields, saw 2\nSkipping line 547424: expected 1 fields, saw 2\nSkipping line 547425: expected 1 fields, saw 2\nSkipping line 547454: expected 1 fields, saw 2\nSkipping line 547463: expected 1 fields, saw 2\nSkipping line 547490: expected 1 fields, saw 2\nSkipping line 547499: expected 1 fields, saw 2\nSkipping line 547504: expected 1 fields, saw 2\nSkipping line 547505: expected 1 fields, saw 2\nSkipping line 547510: expected 1 fields, saw 2\nSkipping line 547511: expected 1 fields, saw 2\nSkipping line 547523: expected 1 fields, saw 2\nSkipping line 547534: expected 1 fields, saw 2\nSkipping line 547564: expected 1 fields, saw 2\nSkipping line 547605: expected 1 fields, saw 2\nSkipping line 547615: expected 1 fields, saw 2\nSkipping line 547626: expected 1 fields, saw 2\nSkipping line 547642: expected 1 fields, saw 2\nSkipping line 547657: expected 1 fields, saw 2\nSkipping line 547686: expected 1 fields, saw 2\nSkipping line 547708: expected 1 fields, saw 2\nSkipping line 547712: expected 1 fields, saw 3\nSkipping line 547718: expected 1 fields, saw 2\nSkipping line 547742: expected 1 fields, saw 3\nSkipping line 547745: expected 1 fields, saw 2\nSkipping line 547775: expected 1 fields, saw 2\nSkipping line 547777: expected 1 fields, saw 3\nSkipping line 547816: expected 1 fields, saw 2\nSkipping line 547845: expected 1 fields, saw 2\nSkipping line 547877: expected 1 fields, saw 2\nSkipping line 547888: expected 1 fields, saw 2\nSkipping line 547904: expected 1 fields, saw 2\nSkipping line 547919: expected 1 fields, saw 2\nSkipping line 547928: expected 1 fields, saw 4\nSkipping line 547949: expected 1 fields, saw 2\nSkipping line 547954: expected 1 fields, saw 4\nSkipping line 547972: expected 1 fields, saw 2\nSkipping line 547989: expected 1 fields, saw 2\nSkipping line 548011: expected 1 fields, saw 2\nSkipping line 548019: expected 1 fields, saw 2\nSkipping line 548023: expected 1 fields, saw 2\nSkipping line 548041: expected 1 fields, saw 2\nSkipping line 548063: expected 1 fields, saw 2\nSkipping line 548092: expected 1 fields, saw 2\nSkipping line 548113: expected 1 fields, saw 2\nSkipping line 548124: expected 1 fields, saw 2\nSkipping line 548140: expected 1 fields, saw 2\nSkipping line 548155: expected 1 fields, saw 2\nSkipping line 548169: expected 1 fields, saw 2\nSkipping line 548178: expected 1 fields, saw 2\nSkipping line 548190: expected 1 fields, saw 2\nSkipping line 548213: expected 1 fields, saw 2\nSkipping line 548227: expected 1 fields, saw 2\nSkipping line 548232: expected 1 fields, saw 2\nSkipping line 548247: expected 1 fields, saw 2\nSkipping line 548264: expected 1 fields, saw 2\nSkipping line 548277: expected 1 fields, saw 2\nSkipping line 548284: expected 1 fields, saw 3\nSkipping line 548286: expected 1 fields, saw 2\nSkipping line 548309: expected 1 fields, saw 3\nSkipping line 548319: expected 1 fields, saw 2\nSkipping line 548357: expected 1 fields, saw 2\nSkipping line 548366: expected 1 fields, saw 3\nSkipping line 548391: expected 1 fields, saw 2\nSkipping line 548403: expected 1 fields, saw 2\nSkipping line 548438: expected 1 fields, saw 2\nSkipping line 548469: expected 1 fields, saw 2\nSkipping line 548479: expected 1 fields, saw 2\nSkipping line 548493: expected 1 fields, saw 2\nSkipping line 548517: expected 1 fields, saw 2\nSkipping line 548548: expected 1 fields, saw 2\nSkipping line 548582: expected 1 fields, saw 3\nSkipping line 548589: expected 1 fields, saw 2\nSkipping line 548602: expected 1 fields, saw 2\nSkipping line 548608: expected 1 fields, saw 2\nSkipping line 548619: expected 1 fields, saw 2\nSkipping line 548655: expected 1 fields, saw 2\nSkipping line 548668: expected 1 fields, saw 2\nSkipping line 548679: expected 1 fields, saw 2\nSkipping line 548685: expected 1 fields, saw 2\nSkipping line 548694: expected 1 fields, saw 2\nSkipping line 548705: expected 1 fields, saw 2\nSkipping line 548734: expected 1 fields, saw 2\nSkipping line  ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df_train
# Out:
#           Please O
# 0           read O
# 1          below O
# 2              ! O
# 3              ! O
# 4        Another O
# ...            ...
# 1428432      his O
# 1428433  younger O
# 1428434  brother O
# 1428435    Bobby O
# 1428436        NaN
#
# [1428437 rows x 1 columns]
